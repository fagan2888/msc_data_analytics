# %% [markdown]
# # Setup

# %% [markdown]
# ###Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# %% [markdown]
# ###Pull data from mongodb

# %%
# import ProximityUserTest
# reload(ProximityUserTest)
# results = ProximityUserTest.UserTestRecords()
# #results.read_constants_from_file('./myConstants_liyuan_proximity.json')
# results.read_constants_from_file('./myConstants.json')
# criterion = """{"metadata.ID": {"$exists": True}}"""
# #criterion = """{"metadata.custom.location": "SF_LEXINGTON"}"""
# results.add_records_from_db(eval(criterion))

# %cd /Users/MariaAthena/Repositories/gesturedataanalysis/resources/
import Achilles
reload(Achilles)
results = Achilles.Achilles()
results.set_constants_from_file("./CONSTANTS.json")
criterion = {"data.output.ThetisProximity": {"$exists": True}}
results.add_records_from_db(criterion)
# Out:
# /Users/MariaAthena/Repositories/gesturedataanalysis/resources
# Achilles: Constants loaded from CONSTANTS.json
# Achilles: Timestamp 15-06-08-19-05-24 already found in records
# Achilles: Timestamp 15-06-08-19-04-55 already found in records
# Achilles: Timestamp 15-06-08-19-04-05 already found in records
# Achilles: Timestamp 15-06-08-19-05-45 already found in records
# Achilles: Timestamp 15-06-08-19-02-25 already found in records
# Achilles: Timestamp 15-06-08-19-05-34 already found in records
# Achilles: Timestamp 15-06-08-19-02-17 already found in records
# Achilles: Timestamp 15-06-08-19-05-49 already found in records
# Achilles: Timestamp 15-06-08-19-03-34 already found in records
# Achilles: Timestamp 15-06-08-19-02-55 already found in records
# Achilles: Timestamp 15-06-08-19-04-15 already found in records
# Achilles: Timestamp 15-06-08-19-03-55 already found in records
# Achilles: Timestamp 15-06-08-19-05-14 already found in records
# Achilles: Timestamp 15-06-08-19-03-15 already found in records
# Achilles: Timestamp 15-06-08-19-05-05 already found in records
# Achilles: Timestamp 15-06-08-19-04-35 already found in records
# Achilles: Timestamp 15-06-08-19-04-44 already found in records
# Achilles: Timestamp 15-06-08-19-03-05 already found in records
# Achilles: Timestamp 15-06-08-19-03-45 already found in records
# Achilles: Timestamp 15-06-08-19-03-25 already found in records
# Achilles: Timestamp 15-06-08-19-02-44 already found in records
# Achilles: Timestamp 15-06-08-19-04-25 already found in records
# Achilles: Added 290 records from collection sandbox in achilles

# %% [markdown]
# ###Compute metrics

# %%
results.add_results()
# Out:
# Achilles: No metrics found in metadata for record 15-06-08-20-00-45_e66cea66-0e27-11e5-899b-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-05-48_e66d973d-0e27-11e5-a251-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-09-18_e66f28b0-0e27-11e5-be46-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-05-49_e66d4ce8-0e27-11e5-85da-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-13-03_e66fb405-0e27-11e5-adf4-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-59-15_e66cd89e-0e27-11e5-a8e7-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-09-38_e66f1bd4-0e27-11e5-b62d-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-39-57_e0e398a3-0e27-11e5-8569-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-19-28-07_e0e2e3d1-0e27-11e5-bbd3-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-20-13-21_e670888f-0e27-11e5-ac1c-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-09-06_e66eb394-0e27-11e5-a357-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-25-17_e0e2bc4a-0e27-11e5-b2a7-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-20-10-04_e66e59cf-0e27-11e5-b39b-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-08-24_e66e2d8c-0e27-11e5-87d1-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-34-44_e0e2fd8f-0e27-11e5-ac9a-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-20-17-52_e670c2a3-0e27-11e5-8cd2-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-05-34_d3637eba-0e27-11e5-a4a4-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-19-02-55_d9c65687-0e27-11e5-81ee-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-20-12-46_e66fc0f5-0e27-11e5-a0c1-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-08-14_e66f353a-0e27-11e5-ae72-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-35-35_e0e31b7d-0e27-11e5-aeb3-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-20-00-00_e66ca0d7-0e27-11e5-96de-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-05-56_e66dc951-0e27-11e5-ad98-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-17-23_e670a8ab-0e27-11e5-aace-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-34-25_e0e34b1c-0e27-11e5-97de-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-20-00-40_e66c9aca-0e27-11e5-942e-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-09-00_e66e6ce8-0e27-11e5-9c54-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-05-08_e66d5935-0e27-11e5-a74c-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-12-53_e67033a3-0e27-11e5-ad19-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-09-09_e66eeee1-0e27-11e5-848d-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-19-36_e670fa28-0e27-11e5-91e6-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-04-48_e66d46cf-0e27-11e5-a420-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-00-22_e66c7bc2-0e27-11e5-b36b-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-26-59_e0e2f7b5-0e27-11e5-ab0f-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-20-09-35_e66f08c5-0e27-11e5-9120-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-12-37_e6700226-0e27-11e5-b914-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-08-19_e66ead35-0e27-11e5-94e9-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-17-39_e670d619-0e27-11e5-8c52-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-13-00_e66fe0f3-0e27-11e5-8806-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-25-57_e0e2d5a3-0e27-11e5-b7e1-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-20-00-31_e66c1f59-0e27-11e5-b339-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-12-48_e66fba82-0e27-11e5-bf45-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-59-49_e66c9487-0e27-11e5-bb7d-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-05-12_e66d6b5e-0e27-11e5-a45e-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-05-07_e66e1aeb-0e27-11e5-8289-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-40-28_e0e3c035-0e27-11e5-a6fe-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-19-27-47_e0e2f1ba-0e27-11e5-a9f9-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-19-03-34_d9c62870-0e27-11e5-b687-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-19-05-49_d3636bb5-0e27-11e5-9606-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-19-59-35_e66cfc66-0e27-11e5-a3d4-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-04-54_e66de8e1-0e27-11e5-82ac-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-19-40_e67109dc-0e27-11e5-b0fc-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-09-56_e66ea61c-0e27-11e5-905f-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-05-05_e66df575-0e27-11e5-8a56-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-40-00_e0e3a6fa-0e27-11e5-b198-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-20-08-55_e66e8cca-0e27-11e5-b0a8-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-05-31_e66d8ae6-0e27-11e5-8dd3-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-04-44_d3639c6b-0e27-11e5-86bd-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-20-17-10_e6709bf0-0e27-11e5-9631-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-00-48_e66c37cc-0e27-11e5-93dc-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-00-59_e66cd2c2-0e27-11e5-a511-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-05-14_d3635d5e-0e27-11e5-ae99-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-20-09-12_e66e46a3-0e27-11e5-bc45-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-04-40_e66d9da6-0e27-11e5-a4f0-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-39-00_e0e4378c-0e27-11e5-9304-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-20-08-28_e66f0251-0e27-11e5-b917-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-41-28_e0e401a3-0e27-11e5-9b61-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-20-04-37_e66d5f4c-0e27-11e5-bed4-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-12-52_e66f8787-0e27-11e5-b384-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-27-37_d9c729e6-0e27-11e5-bfe4-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-20-12-50_e66f8de6-0e27-11e5-a2cd-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-33-54_e0e3453d-0e27-11e5-b5c1-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-20-13-01_e6701deb-0e27-11e5-bc3b-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-17-49_e670e307-0e27-11e5-9f3c-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-08-21_e66e33d7-0e27-11e5-94fb-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-25-47_d9c709b5-0e27-11e5-9c81-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-20-05-15_e66d0fd1-0e27-11e5-9a5c-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-12-35_e66f54e8-0e27-11e5-ae6a-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-59-46_e66c2bb0-0e27-11e5-9e3b-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-05-36_e66d718c-0e27-11e5-aa46-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-12-38_e66f74bd-0e27-11e5-b80e-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-08-44_e66e3a40-0e27-11e5-9e53-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-12-44_e66fef99-0e27-11e5-a18b-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-04-55_e66daa4c-0e27-11e5-b12b-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-03-05_d9c603fd-0e27-11e5-99b8-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-20-19-28_e6710f02-0e27-11e5-abe5-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-05-38_e66d095e-0e27-11e5-b0f1-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-00-08_e66c31dc-0e27-11e5-858c-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-04-25_d9c63f5e-0e27-11e5-a3b6-7cd1c3ef9fbb
# ...
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-20-00-37_e66ce47d-0e27-11e5-805d-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-25-08_d9c6ed26-0e27-11e5-8bb8-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-19-03-55_d36384d1-0e27-11e5-94b0-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-19-38-49_e0e3ccf0-0e27-11e5-9489-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-20-05-34_e66d281c-0e27-11e5-a36f-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-25-27_d9c7237d-0e27-11e5-a578-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-19-39-09_e0e38c35-0e27-11e5-84a9-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-20-05-41_e66dfb97-0e27-11e5-8608-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-08-46_e66e9fb3-0e27-11e5-9adf-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-05-27_e66db063-0e27-11e5-ac90-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-17-04_e670dc8a-0e27-11e5-bf9b-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-09-47_e66f4823-0e27-11e5-b856-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-05-51_e66d849c-0e27-11e5-94fd-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-41-47_e0e4292b-0e27-11e5-a98c-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-19-34-15_e0e327ca-0e27-11e5-a601-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-20-13-16_e67026a1-0e27-11e5-b197-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-05-05_d361ad0f-0e27-11e5-94a8-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-20-17-42_e670cfba-0e27-11e5-8602-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-59-21_e66c2570-0e27-11e5-aef4-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-17-13_e670e9ae-0e27-11e5-bbe1-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-32-25_e0e362f8-0e27-11e5-950c-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: Not enough data in group "all-timestamps.output.ThetisProximity.touch" to compute statistics
# Achilles: No metrics found in metadata for record 15-06-08-20-05-04_e66d9130-0e27-11e5-bfd8-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-12-59_e6707b85-0e27-11e5-91c2-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-19-59-54_e66c5700-0e27-11e5-865a-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-09-23_e66ed9d1-0e27-11e5-8720-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-00-10_e66c0459-0e27-11e5-8881-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp
# Achilles: No metrics found in metadata for record 15-06-08-20-13-20_e66fc728-0e27-11e5-80cb-7cd1c3ef9fbb
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.proximity" default to first timestamp
# Achilles: No timestamp column found in group "all-timestamps.output.ThetisProximity.raw", cannot compute statistics
# Achilles: No timestamp request found in group "all-timestamps.output.ThetisProximity.touch" default to first timestamp

# %%
polarities = [
    record.get("metadata.truth.gesture.polarity", "I have no polarity!") for record in results.records.values()
]
for p in polarities:
    print p
# Out:
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Negative
# Negative
# Positive
# Positive
# Negative
# Positive
# Positive
# Negative
# Positive
# Negative
# Negative
# Positive
# Positive
# Negative
# Positive
# Positive
# Positive
# Negative
# Positive
# Positive
# Positive
# Positive
# Positive
# I have no polarity!
# Positive
# Positive
# Negative
# Positive
# Positive
# Positive
# Positive
# Positive
# Negative
# Positive
# Positive
# Positive
# Positive
# Positive
# Negative
# Negative
# Negative
# Negative
# Positive
# Positive
# I have no polarity!
# Positive
# Positive
# Negative
# Positive
# Positive
# Negative
# Positive
# Positive
# Positive
# Negative
# Positive
# Positive
# Negative
# Positive
# Negative
# Positive
# Positive
# Negative
# Positive
# Negative
# Positive
# Positive
# Positive
# Negative
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Negative
# I have no polarity!
# Positive
# Positive
# Negative
# Positive
# Positive
# I have no polarity!
# Negative
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Negative
# Negative
# Positive
# Positive
# Negative
# Positive
# Positive
# Negative
# Positive
# Positive
# Negative
# Negative
# Positive
# Positive
# Positive
# Positive
# I have no polarity!
# Negative
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Negative
# Positive
# Positive
# Positive
# Positive
# Negative
# Negative
# Negative
# Negative
# Negative
# Positive
# Positive
# Negative
# Positive
# Negative
# Negative
# Negative
# Positive
# Negative
# Positive
# I have no polarity!
# Positive
# Positive
# Negative
# Positive
# Negative
# Positive
# Negative
# Positive
# I have no polarity!
# Positive
# Positive
# Positive
# Positive
# Negative
# Positive
# Positive
# Negative
# Positive
# Positive
# Positive
# Negative
# I have no polarity!
# Negative
# Positive
# Positive
# Negative
# Positive
# Positive
# Positive
# Negative
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Negative
# Positive
# Positive
# Negative
# Positive
# Positive
# Negative
# Positive
# Positive
# Positive
# Negative
# Positive
# Positive
# Negative
# Negative
# Negative
# Positive
# Positive
# Negative
# Positive
# Positive
# Positive
# Negative
# Positive
# Positive
# Negative
# Positive
# I have no polarity!
# Positive
# Positive
# Positive
# Negative
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Negative
# Positive
# Positive
# Positive
# Positive
# Positive
# Negative
# Positive
# Negative
# Positive
# Positive
# Negative
# Positive
# Positive
# Negative
# Positive
# Negative
# Positive
# Positive
# Positive
# Negative
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Negative
# Positive
# Positive
# Positive
# Positive
# Negative
# Negative
# Positive
# Negative
# Negative
# Negative
# Positive
# Negative
# Negative
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive
# Negative
# Negative
# Positive
# Negative
# Positive
# Positive
# Positive
# Negative
# Positive
# Positive
# Positive
# Positive
# Positive
# Positive

# %%
df = pd.DataFrame([record for record in results.records.values()])
for column in df.columns:
    print column
# Out:
# _id
# _results.stats.all-timestamps.output.ThetisProximity.proximity.count
# _results.stats.all-timestamps.output.ThetisProximity.proximity.first-ts
# _results.stats.all-timestamps.output.ThetisProximity.touch.count
# _results.stats.all-timestamps.output.ThetisProximity.touch.first-ts
# _results.stats.all-timestamps.output.ThetisProximity.touch.ir.abs.nonzero.count
# _results.stats.all-timestamps.output.ThetisProximity.touch.ir.abs.nonzero.first
# _results.stats.all-timestamps.output.ThetisProximity.touch.ir.abs.nonzero.ratio
# _results.stats.all-timestamps.output.ThetisProximity.touch.r.abs.finite.count
# _results.stats.all-timestamps.output.ThetisProximity.touch.r.abs.finite.mean
# _results.stats.all-timestamps.output.ThetisProximity.touch.r.abs.finite.ratio
# _results.stats.all-timestamps.output.ThetisProximity.touch.r.abs.lt_threshold.10.count
# _results.stats.all-timestamps.output.ThetisProximity.touch.r.abs.lt_threshold.10.first
# _results.stats.all-timestamps.output.ThetisProximity.touch.r.abs.lt_threshold.10.ratio
# _results.stats.all-timestamps.output.ThetisProximity.touch.r.abs.lt_threshold.15.count
# _results.stats.all-timestamps.output.ThetisProximity.touch.r.abs.lt_threshold.15.first
# _results.stats.all-timestamps.output.ThetisProximity.touch.r.abs.lt_threshold.15.ratio
# _results.stats.all-timestamps.output.ThetisProximity.touch.r.abs.lt_threshold.20.count
# _results.stats.all-timestamps.output.ThetisProximity.touch.r.abs.lt_threshold.20.first
# _results.stats.all-timestamps.output.ThetisProximity.touch.r.abs.lt_threshold.20.ratio
# _results.stats.all-timestamps.output.ThetisProximity.touch.r.abs.lt_threshold.30.count
# _results.stats.all-timestamps.output.ThetisProximity.touch.r.abs.lt_threshold.30.first
# _results.stats.all-timestamps.output.ThetisProximity.touch.r.abs.lt_threshold.30.ratio
# _results.stats.all-timestamps.output.ThetisProximity.touch.r.abs.lt_threshold.50.count
# _results.stats.all-timestamps.output.ThetisProximity.touch.r.abs.lt_threshold.50.first
# _results.stats.all-timestamps.output.ThetisProximity.touch.r.abs.lt_threshold.50.ratio
# _results.stats.all-timestamps.output.ThetisProximity.touch.r.abs.values.first
# _results.stats.all-timestamps.output.ThetisProximity.touch.r.abs.values.mean
# _results.stats.all-timestamps.output.ThetisProximity.touch.us.abs.nonzero.count
# _results.stats.all-timestamps.output.ThetisProximity.touch.us.abs.nonzero.first
# _results.stats.all-timestamps.output.ThetisProximity.touch.us.abs.nonzero.ratio
# data.output.ThetisProximity.proximity.ir
# data.output.ThetisProximity.proximity.r
# data.output.ThetisProximity.proximity.state
# data.output.ThetisProximity.proximity.time
# data.output.ThetisProximity.proximity.us
# data.output.ThetisProximity.raw.Position
# data.output.ThetisProximity.raw.Time
# data.output.ThetisProximity.raw.Type
# data.output.ThetisProximity.touch.ir
# data.output.ThetisProximity.touch.r
# data.output.ThetisProximity.touch.state
# data.output.ThetisProximity.touch.time
# data.output.ThetisProximity.touch.touch-x
# data.output.ThetisProximity.touch.touch-y
# data.output.ThetisProximity.touch.us
# experiment.timestamp.iso
# experiment.timestamp.posix
# experiment.timestamp.str
# metadata.custom.date
# metadata.custom.location
# metadata.custom.user
# metadata.system.codec.firmware
# metadata.system.codec.serial
# metadata.system.engine.version
# metadata.system.firmware.build.description
# metadata.system.firmware.build.type
# metadata.system.firmware.build.user
# metadata.system.firmware.build.version.incremental
# metadata.system.firmware.build.version.release
# metadata.system.firmware.build.version.sdk
# metadata.system.firmware.product.brand
# metadata.system.firmware.product.model
# metadata.system.firmware.product.name
# metadata.system.firmware.serialno
# metadata.truth.environment.initial_state
# metadata.truth.gesture.approach
# metadata.truth.gesture.hand_pose
# metadata.truth.gesture.polarity
# metadata.truth.gesture.reflector
# metadata.truth.gesture.touch.angle
# metadata.truth.gesture.touch.column
# metadata.truth.gesture.touch.event
# metadata.truth.gesture.touch.row

# %%
ULTRASOUND_DETECTION_THRESHOLD = 40 # mm
results.compute_metrics(ULTRASOUND_DETECTION_THRESHOLD)

df = results.as_df()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-84c580effa5e> in <module>()
#       1 ULTRASOUND_DETECTION_THRESHOLD = 40 # mm
# ----> 2 results.compute_metrics(ULTRASOUND_DETECTION_THRESHOLD)
#       3
#       4 df = results.as_df()
#
# AttributeError: 'Achilles' object has no attribute 'compute_metrics'

# %%
df.columns
# Out:
# Index([u'_id', u'data.output.first_ts', u'data.output.parsed.ir.r', u'data.output.parsed.ir.time', u'data.output.parsed.ir.type', u'data.output.parsed.touch.time', u'data.output.parsed.touch.type', u'data.output.parsed.touch.x', u'data.output.parsed.touch.y', u'data.output.parsed.us.r', u'data.output.parsed.us.time', u'data.output.parsed.us.type', u'data.output.raw.pos', u'data.output.raw.time', u'data.output.raw.type', u'experiment.ts.iso', u'experiment.ts.posix', u'metadata.ID', u'metadata.custom.location', u'metadata.custom.user', u'metadata.deliverable', u'metadata.expectation', u'metadata.grip', u'metadata.initial_condition', u'metadata.method', u'metadata.polarity', u'metadata.reflector', u'metadata.system.engine.version', u'metadata.system.firmware.build.description', u'metadata.system.firmware.build.type', u'metadata.system.firmware.build.user', u'metadata.system.firmware.build.version.incremental', u'metadata.system.firmware.build.version.release', u'metadata.system.firmware.build.version.sdk', u'metadata.system.firmware.product.brand', u'metadata.system.firmware.product.model', u'metadata.system.firmware.product.name', u'metadata.system.firmware.serialno', u'metadata.touch_event', u'results.metrics.prox.at_touch.count', u'results.metrics.prox.at_touch.detected', u'results.metrics.prox.at_touch.ir.all.lt_threshold', u'results.metrics.prox.at_touch.ir.all.lt_threshold_count', u'results.metrics.prox.at_touch.ir.all.lt_threshold_ratio', u'results.metrics.prox.at_touch.ir.first.lt_threshold', u'results.metrics.prox.at_touch.us.all.age', u'results.metrics.prox.at_touch.us.all.detected', u'results.metrics.prox.at_touch.us.all.detected_count', u'results.metrics.prox.at_touch.us.all.detected_ratio', u'results.metrics.prox.at_touch.us.all.lt_threshold', u'results.metrics.prox.at_touch.us.all.lt_threshold_count', u'results.metrics.prox.at_touch.us.all.lt_threshold_ratio', u'results.metrics.prox.at_touch.us.all.r', u'results.metrics.prox.at_touch.us.first.age', u'results.metrics.prox.at_touch.us.first.detected', u'results.metrics.prox.at_touch.us.first.lt_threshold', u'results.metrics.prox.at_touch.us.first.r', u'timestamp'], dtype='object')

# %% [markdown]
# ### Set temporary variables

# %%
COUNT_OF_TOUCH_EVENTS               = "results.metrics.prox.at_touch.count"
ULTRASOUND_DIST_AT_FIRST_TOUCH      = "results.metrics.prox.at_touch.us.first.r"
ULTRASOUND_PROX_DATA_AT_FIRST_TOUCH = "results.metrics.prox.at_touch.us.first.detected"
ULTRASOUND_PROX_DATA_ALL_TOUCHES    = "results.metrics.prox.at_touch.us.all.detected"
ULTRASOUND_PROX_NEAR_AT_FIRST_TOUCH = "results.metrics.prox.at_touch.us.first.lt_threshold"
ULTRASOUND_PROX_NEAR_ALL_TOUCHES    = "results.metrics.prox.at_touch.us.all.lt_threshold"
INFRARED_PROX_NEAR_AT_FIRST_TOUCH   = "results.metrics.prox.at_touch.ir.first.lt_threshold"
INFRARED_PROX_NEAR_ALL_TOUCHES      = "results.metrics.prox.at_touch.ir.all.lt_threshold"

# %% [markdown]
# ### Separate data into subdatasets

# %%
# Create sub dataframes
df_pos = df.loc[(df["metadata.polarity"] == "Positive") & (df[COUNT_OF_TOUCH_EVENTS] > 0)] # Remove data points with no touch events
df_pos_us_detect = df_pos[df_pos[ULTRASOUND_PROX_DATA_AT_FIRST_TOUCH]] # Remove data points which have no ultrasound detected at first touch
df_neg_no_touch = df.loc[(df["metadata.polarity"] == "Negative") & (df["metadata.touch_event"] == "None")]
df_neg_touch = df.loc[(df["metadata.polarity"] == "Negative") & (df["metadata.touch_event"] != "None") & (df[COUNT_OF_TOUCH_EVENTS] > 0)] # Remove data points with no touch events

# %% [markdown]
# ###Aggregate functions for analysis

# %%
def agg_func_sum_of_length_of_arrays(x): return(sum([len(y) for y in x]))
def agg_func_sum_of_number_of_true_elements_in_arrays(x): return(sum([len(y.nonzero()[0]) for y in x]))
def agg_func_count_records_with_val_greater_than_zero(x): return(len((x > 0).nonzero()[0]))
def agg_func_count_records_with_val_true(x): return(len((x == True).nonzero()[0]))

# %% [markdown]
# ###Identify touch location

# %%
TOUCH_ROW = 'touch_row'
TOUCH_COL = 'touch_column'
TOUCH_ANGLE = 'touch_angle'
match_pattern = r'.+(Grid (?P<'+TOUCH_ROW+'>\d)(?P<'+TOUCH_COL+'>\w))'
match_pattern_row = r'.+(Grid (?P<'+TOUCH_ROW+'>\d)\w)'
match_pattern_column = r'.+(Grid \d(?P<'+TOUCH_COL+'>\w))'
match_pattern_angle = r'.+fingers at (?P<'+TOUCH_ANGLE+'>\d+) deg.+'
touch_matches_row = df_neg_touch['metadata.grip'].apply(lambda x: re.match(match_pattern_row,x).groupdict()[TOUCH_ROW])
touch_matches_col = df_neg_touch['metadata.grip'].apply(lambda x: re.match(match_pattern_column,x).groupdict()[TOUCH_COL])
touch_matches_angle = df_neg_touch['metadata.grip'].apply(lambda x: re.match(match_pattern_angle,x).groupdict()[TOUCH_ANGLE])
# Following commands create warning messages: fix?
df_neg_touch['touch_row'] = touch_matches_row
df_neg_touch['touch_col'] = touch_matches_col
df_neg_touch['touch_angle'] = touch_matches_angle
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/kernel/__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/kernel/__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/kernel/__main__.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### Set up plotting environment

# %%
# Optional -- this makes the graphs look nicer
import seaborn as sns
reload(sns)
# This only works in jupyter -- you'll have to export your plots to a file if you use the ipython console
# %pylab inline
titleargs = {'fontsize': 12}
sns.set(font_scale=1.25)
sns.set_style("whitegrid")
sns.despine
rcParams['font.family'] = 'monospace'
pylab.rcParams['figure.figsize'] = (12.0, 10.0)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Performance charts

# %% [markdown]
# ###Ratio of records with ultrasound data at touch event vs those with no ultrasound data

# %%
# Barplot of counts (not normalized)
grouped_pos = df_pos.groupby(
    ["metadata.initial_condition",
     "metadata.reflector",
     "metadata.touch_event",
     ULTRASOUND_PROX_DATA_AT_FIRST_TOUCH])
grouped_pos_us_detected = grouped_pos['_id'].count().unstack(ULTRASOUND_PROX_DATA_AT_FIRST_TOUCH).fillna(0)
barplot = grouped_pos_us_detected.plot(kind='barh', stacked=True, legend=True)
barplot.set_ylabel('Initial condition, Reflector, Touch event')
barplot.set_xlabel('Count of tests')
barplot.set_title('Count of ultrasound detections at first touch\nFalse: no ultrasound data, True: ultrasound data')
plt.tight_layout()
plt.savefig(results.PLOT_FOLDER+'Count_of_ultrasound_detections_at_first_touch.png',dpi=200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f37f84ab79a4> in <module>()
#       1 # Barplot of counts (not normalized)
# ----> 2 grouped_pos = df_pos.groupby(
#       3     ["metadata.initial_condition",
#       4      "metadata.reflector",
#       5      "metadata.touch_event",
#
# NameError: name 'df_pos' is not defined

# %%
# Barplot of ratios (normalized)
grouped_pos = df_pos.groupby(
    ["metadata.initial_condition",
     "metadata.reflector",
     "metadata.touch_event",
     ULTRASOUND_PROX_DATA_AT_FIRST_TOUCH])
grouped_pos_us_detected = grouped_pos['_id'].count().unstack(ULTRASOUND_PROX_DATA_AT_FIRST_TOUCH).fillna(0)
barplot = grouped_pos_us_detected.div(grouped_pos_us_detected.sum(1),axis=0).plot(kind='barh', stacked=True, legend=True)
barplot.set_ylabel('Initial condition, Reflector, Touch event')
barplot.set_ylabel('')
barplot.set_xlabel('')
barplot.set_title('Distribution of ultrasound detections at first touch\nFalse: no ultrasound data, True: ultrasound data')
plt.tight_layout()
plt.savefig(results.PLOT_FOLDER+'Ultrasound_detections_distribution.png',dpi=200)

# %% [markdown]
# ### Ratio of records with ultrasound proximity detected (depends on threshold)

# %%
# Barplot of counts (not normalized)
grouped_pos = df_pos.groupby(
    ["metadata.initial_condition",
     "metadata.reflector",
     "metadata.touch_event",
     ULTRASOUND_PROX_NEAR_AT_FIRST_TOUCH])
grouped_pos_us_detected = grouped_pos['_id'].count().unstack(ULTRASOUND_PROX_NEAR_AT_FIRST_TOUCH).fillna(0)
barplot = grouped_pos_us_detected.plot(kind='barh', stacked=True, legend=True)
barplot.set_ylabel('Initial condition, Reflector, Touch event')
barplot.set_xlabel('Count of tests')
barplot.set_title('Count of ultrasound proximity at first touch\nFalse: proximity failure, True: proximity success')
plt.tight_layout()
plt.savefig(results.PLOT_FOLDER+'Count_of_ultrasound_proximity_at_first_touch.png',dpi=200)

# %%
# Barplot of ratios (normalized)
grouped_pos = df_pos.groupby(
    ["metadata.initial_condition",
     "metadata.reflector",
     "metadata.touch_event",
     ULTRASOUND_PROX_NEAR_AT_FIRST_TOUCH])
grouped_pos_us_detected = grouped_pos['_id'].count().unstack(ULTRASOUND_PROX_NEAR_AT_FIRST_TOUCH).fillna(0)
barplot = grouped_pos_us_detected.div(grouped_pos_us_detected.sum(1),axis=0).plot(kind='barh', stacked=True, legend=True)
barplot.set_ylabel('Initial condition, Reflector, Touch event')
barplot.set_xlabel('')
barplot.set_title('Distribution of ultrasound proximity at first touch\nFalse: proximity failure, True: proximity success')
plt.tight_layout()
plt.savefig(results.PLOT_FOLDER+'Distribution_of_ultrasound_proximity_at_first_touch.png',dpi=200)

# %% [markdown]
# ### Ratio of records with infrared proximity detected

# %%
grouped_pos = df_pos.groupby(
    ["metadata.initial_condition",
     "metadata.reflector",
     "metadata.touch_event",
     INFRARED_PROX_NEAR_AT_FIRST_TOUCH])
grouped_pos_us_detected = grouped_pos['_id'].count().unstack(INFRARED_PROX_NEAR_AT_FIRST_TOUCH).fillna(0)
barplot = grouped_pos_us_detected.plot(kind='barh', stacked=True, legend=True)
barplot.set_ylabel('Initial condition, Reflector, Touch event')
barplot.set_xlabel('Count of tests')
barplot.set_title('Count of infrared proximity at first touch\nFalse: proximity failure, True: proximity success')
plt.tight_layout()
plt.savefig(results.PLOT_FOLDER+'Count_of_infrared_proximity_at_first_touch.png',dpi=200)

# %%
grouped_pos = df_pos.groupby(
    ["metadata.initial_condition",
     "metadata.reflector",
     "metadata.touch_event",
     INFRARED_PROX_NEAR_AT_FIRST_TOUCH])
grouped_pos_us_detected = grouped_pos['_id'].count().unstack(INFRARED_PROX_NEAR_AT_FIRST_TOUCH).fillna(0)
barplot = grouped_pos_us_detected.div(grouped_pos_us_detected.sum(1),axis=0).plot(kind='barh', stacked=True, legend=True)
barplot.set_ylabel('Initial condition, Reflector, Touch event')
barplot.set_xlabel('')
barplot.set_title('Distribution of infrared proximity at first touch\nFalse: proximity failure, True: proximity success')
plt.tight_layout()
plt.savefig(results.PLOT_FOLDER+'Distribution_of_infrared_proximity_at_first_touch.png',dpi=200)

# %% [markdown]
# ### Performance comparison based on head-approach methods

# %%
detection_count_comp = df_pos.pivot_table(values=[ULTRASOUND_PROX_DATA_AT_FIRST_TOUCH,
                                                  ULTRASOUND_PROX_NEAR_AT_FIRST_TOUCH,
                                                  INFRARED_PROX_NEAR_AT_FIRST_TOUCH],
                  columns=["metadata.touch_event"],
                  aggfunc=agg_func_count_records_with_val_true)
all_count_comp = df_pos.pivot_table(values=[ULTRASOUND_PROX_DATA_AT_FIRST_TOUCH,
                                              ULTRASOUND_PROX_NEAR_AT_FIRST_TOUCH,
                                              INFRARED_PROX_NEAR_AT_FIRST_TOUCH],
                  columns=["metadata.touch_event"],
                  aggfunc=len)
barplot = (detection_count_comp / all_count_comp).plot(kind='barh', stacked=False, legend=True)

# %% [markdown]
# ### Performance comparison based on initial condition

# %%
df_pos_normal_approach = df_pos[(df_pos['metadata.touch_event'] == 'Ear only') | (df_pos['metadata.touch_event'] == 'Ear and cheek')]
detection_count_comp = df_pos_normal_approach.pivot_table(values=[ULTRASOUND_PROX_DATA_AT_FIRST_TOUCH,
                                                                  ULTRASOUND_PROX_NEAR_AT_FIRST_TOUCH,
                                                                  INFRARED_PROX_NEAR_AT_FIRST_TOUCH],
                  columns=["metadata.initial_condition"],
                  aggfunc=agg_func_count_records_with_val_true)
all_count_comp = df_pos_normal_approach.pivot_table(values=[ULTRASOUND_PROX_DATA_AT_FIRST_TOUCH,
                                                  ULTRASOUND_PROX_NEAR_AT_FIRST_TOUCH,
                                                  INFRARED_PROX_NEAR_AT_FIRST_TOUCH],
                  columns=["metadata.initial_condition"],
                  aggfunc=len)
barplot = (detection_count_comp / all_count_comp).plot(kind='barh', stacked=False, legend=True)

# %% [markdown]
# ### Performance comparison based on headgear

# %%
df_pos_normal_approach = df_pos[(df_pos['metadata.touch_event'] == 'Ear only') | (df_pos['metadata.touch_event'] == 'Ear and cheek')]
detection_count_comp = df_pos_normal_approach.pivot_table(values=[ULTRASOUND_PROX_DATA_AT_FIRST_TOUCH,
                                                                  ULTRASOUND_PROX_NEAR_AT_FIRST_TOUCH,
                                                                  INFRARED_PROX_NEAR_AT_FIRST_TOUCH],
                  columns=["metadata.reflector"],
                  aggfunc=agg_func_count_records_with_val_true)
all_count_comp = df_pos_normal_approach.pivot_table(values=[ULTRASOUND_PROX_DATA_AT_FIRST_TOUCH,
                                                              ULTRASOUND_PROX_NEAR_AT_FIRST_TOUCH,
                                                              INFRARED_PROX_NEAR_AT_FIRST_TOUCH],
                  columns=["metadata.reflector"],
                  aggfunc=len)
barplot = (detection_count_comp / all_count_comp).plot(kind='barh', stacked=False, legend=True)

# %% [markdown]
# # Sanity checks (tables)

# %%
df.pivot_table(index=['metadata.polarity', 'metadata.reflector', 'metadata.touch_event', 'metadata.initial_condition'],
               values='_id',
               columns=['metadata.system.engine.version', 'metadata.custom.location'],
               aggfunc=len)
# Out:
# metadata.system.engine.version                                                           Version 1.3.20331.5.
# metadata.custom.location                                                                         SF_LEXINGTON
# metadata.polarity metadata.reflector metadata.touch_event metadata.initial_condition
# Negative          Environment        Finger               Open space                                       36
#                                      None                 Gently tapping/squeezing frame                    1
#                                                           Open space                                       43
# Positive          Head-- no hat      Ear and cheek        Open space                                       94
#                                                           Table-- facing down                             102
#                                      Ear only             Open space                                       84
#                                                           Table-- facing down                             115
#                                      Roll on cheek        Open space                                       62
#                                                           Table-- facing down                              54
#                   Head-- thin fabric Ear and cheek        Open space                                       50
#                                      Ear only             Open space                                       59
#                                      Roll on cheek        Open space                                       59

# %% [markdown]
# ### Total number of records in database

# %%
df.pivot_table(index=['metadata.polarity','metadata.reflector','metadata.touch_event','metadata.initial_condition','metadata.grip'],
               values='_id',
               columns=['metadata.system.engine.version','metadata.system.firmware.serialno',],
               aggfunc=len)
# Out:
# metadata.system.engine.version                                                                                                                  Version 1.3.20331.5.
# metadata.system.firmware.serialno                                                                                                                           8b286d06
# metadata.polarity metadata.reflector metadata.touch_event metadata.initial_condition     metadata.grip
# Negative          Environment        Finger               Open space                     Table-- touching fingers at 45 deg (1.C) (Grid 1A)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 1B)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 1C)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 2A)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 2B)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 2C)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 3A)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 3B)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 3C)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 4A)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 4B)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 4C)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 5A)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 5B)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 5C)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 6A)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 6B)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 6C)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 1A)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 1B)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 1C)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 2A)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 2B)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 2C)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 3A)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 3B)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 3C)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 4A)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 4B)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 4C)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 5A)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 5B)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 5C)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 6A)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 6B)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 6C)                        1
#                                      None                 Gently tapping/squeezing frame Hand-- no fingers sticking out (3.A)                                      1
#                                                           Open space                     Hand-- fingers sticking out (middle)-- no motion (3.B)                   10
#                                                                                          Hand-- fingers sticking out (middle)-- wiggling (3.B)                     9
#                                                                                          Hand-- fingers sticking out (top)-- no motion (3.C)                      12
#                                                                                          Hand-- fingers sticking out (top)-- wiggling (3.C)                       12
# Positive          Head-- no hat      Ear and cheek        Open space                     Hand-- no fingers sticking out (4.A) FAST                                53
#                                                                                          Hand-- no fingers sticking out (4.A) SLOW                                41
#                                                           Table-- facing down            Hand-- no fingers sticking out (4.A) FAST                                53
#                                                                                          Hand-- no fingers sticking out (4.A) SLOW                                49
#                                      Ear only             Open space                     Hand-- no fingers sticking out (4.A) FAST                                55
#                                                                                          Hand-- no fingers sticking out (4.A) SLOW                                29
#                                                           Table-- facing down            Hand-- no fingers sticking out (4.A) FAST                                58
#                                                                                          Hand-- no fingers sticking out (4.A) SLOW                                57
#                                      Roll on cheek        Open space                     Hand-- no fingers sticking out (4.B)                                     62
#                                                           Table-- facing down            Hand-- no fingers sticking out (4.B)                                     54
#                   Head-- thin fabric Ear and cheek        Open space                     Hand-- no fingers sticking out (4.A)                                     50
#                                      Ear only             Open space                     Hand-- no fingers sticking out (4.A)                                     59
#                                      Roll on cheek        Open space                     Hand-- no fingers sticking out (4.B)                                     59

# %% [markdown]
# ### Number of records which include at least one touch event

# %%
df.pivot_table(index=['metadata.polarity','metadata.reflector','metadata.touch_event','metadata.initial_condition','metadata.grip'],
               values=COUNT_OF_TOUCH_EVENTS,
               columns=['metadata.system.firmware.serialno','metadata.system.engine.version'],
               aggfunc=agg_func_count_records_with_val_greater_than_zero)
# Out:
# metadata.system.firmware.serialno                                                                                                                           8b286d06
# metadata.system.engine.version                                                                                                                  Version 1.3.20331.5.
# metadata.polarity metadata.reflector metadata.touch_event metadata.initial_condition     metadata.grip
# Negative          Environment        Finger               Open space                     Table-- touching fingers at 45 deg (1.C) (Grid 1A)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 1B)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 1C)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 2A)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 2B)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 2C)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 3A)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 3B)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 3C)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 4A)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 4B)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 4C)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 5A)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 5B)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 5C)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 6A)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 6B)                        1
#                                                                                          Table-- touching fingers at 45 deg (1.C) (Grid 6C)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 1A)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 1B)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 1C)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 2A)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 2B)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 2C)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 3A)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 3B)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 3C)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 4A)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 4B)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 4C)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 5A)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 5B)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 5C)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 6A)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 6B)                        1
#                                                                                          Table-- touching fingers at 90 deg (1.B) (Grid 6C)                        1
#                                      None                 Gently tapping/squeezing frame Hand-- no fingers sticking out (3.A)                                      0
#                                                           Open space                     Hand-- fingers sticking out (middle)-- no motion (3.B)                    0
#                                                                                          Hand-- fingers sticking out (middle)-- wiggling (3.B)                     0
#                                                                                          Hand-- fingers sticking out (top)-- no motion (3.C)                       0
#                                                                                          Hand-- fingers sticking out (top)-- wiggling (3.C)                        0
# Positive          Head-- no hat      Ear and cheek        Open space                     Hand-- no fingers sticking out (4.A) FAST                                53
#                                                                                          Hand-- no fingers sticking out (4.A) SLOW                                41
#                                                           Table-- facing down            Hand-- no fingers sticking out (4.A) FAST                                53
#                                                                                          Hand-- no fingers sticking out (4.A) SLOW                                49
#                                      Ear only             Open space                     Hand-- no fingers sticking out (4.A) FAST                                55
#                                                                                          Hand-- no fingers sticking out (4.A) SLOW                                29
#                                                           Table-- facing down            Hand-- no fingers sticking out (4.A) FAST                                58
#                                                                                          Hand-- no fingers sticking out (4.A) SLOW                                57
#                                      Roll on cheek        Open space                     Hand-- no fingers sticking out (4.B)                                     62
#                                                           Table-- facing down            Hand-- no fingers sticking out (4.B)                                     54
#                   Head-- thin fabric Ear and cheek        Open space                     Hand-- no fingers sticking out (4.A)                                     50
#                                      Ear only             Open space                     Hand-- no fingers sticking out (4.A)                                      3
#                                      Roll on cheek        Open space                     Hand-- no fingers sticking out (4.B)                                     59

# %% [markdown]
# # Miscellaneous

# %% [markdown]
# ###Violin plots of distance at touch (ultrasound)

# %%
this_df = df_pos_us_detect

group_param = 'metadata.initial_condition'
param_name = 'metadata.reflector'

unique_params = this_df[param_name].unique()
unique_params_cnt = len(unique_params)
fig, all_axes = plt.subplots(unique_params_cnt, 1)
# Matplotlib is ridiculous and returns a scalar instead of an array if the number of plots is one, hence:
if type(all_axes) != type(np.array([])):
    all_axes = np.asarray([all_axes])

for idx, this_param in enumerate(unique_params):
    subset_idx = (this_df[param_name] == this_param)
    vp = sns.violinplot(vals=this_df[ULTRASOUND_DIST_AT_FIRST_TOUCH][subset_idx],
                       groupby=this_df[group_param][subset_idx],
                       inner="stick",
                       vert=False,
                       cut=1,
                       bw=.1,
                       ax=all_axes[idx])
    vp.set_xlim([0,130])
    vp.legend()
    subplot_title = param_name + ': ' + this_param
    if idx == 0:
        subplot_title = 'Distribution of '+ULTRASOUND_DIST_AT_FIRST_TOUCH+'\n'+subplot_title
    vp.set_title(subplot_title)
    vp.set_xlabel('Distance [mm]')
    vp.set_ylabel(group_param)
plt.tight_layout() 
plt.savefig('cool_violins.png',dpi=200)

# %% [markdown]
# ### Estimate of a posteriori detection rate based on threshold

# %%
detect_threshold_array = [10, 15, 20, 25, 30, 35, 40, 50, 60, 70]
for threshold_idx, detect_threshold in enumerate(detect_threshold_array):
    df_all = df.copy()
    df_all['detected'] = df[ULTRASOUND_DIST_AT_FIRST_TOUCH] < detect_threshold
    df_detected = df_all[df_all['detected']]
    group_true_detect = df_detected.groupby(['metadata.initial_condition','metadata.reflector','metadata.touch_event'])['_id'].count().fillna(0)
    group_all_detect  = df_all.groupby(['metadata.initial_condition','metadata.reflector','metadata.touch_event'])['_id'].count().fillna(0)
    group_fractional_detect = group_true_detect/group_all_detect
    print "Threshold: " + str(detect_threshold) + " mm"
    print group_fractional_detect

# %%
this_df = df_pos_us_detect
group_param = 'metadata.initial_condition'
param_name = 'metadata.reflector'
plt_grid = sns.FacetGrid(this_df, col=param_name, hue=group_param)
plt_grid.map(sns.distplot, ULTRASOUND_DIST_AT_FIRST_TOUCH, bins=np.arange(0, 60, 5),hist_kws={'alpha':.2})
plt_grid.set(xlabel='')
plt_grid.set(xlim=[0,60])
plt_grid.set(ylim=[0,0.2])
#with sns.axes_style("white"):
#    sns.distplot(this_df[ULTRASOUND_DIST_AT_FIRST_TOUCH]);

# %%
bp = df_pos_us_detect.boxplot(column=ULTRASOUND_DIST_AT_FIRST_TOUCH, by=['metadata.initial_condition','metadata.reflector'], vert=False)
bp.set_xlim([0,60])

# %% [markdown]
# ###Count of all touch events in negative (touch) test set

# %%
df_neg_touch.pivot_table(index=['metadata.polarity','metadata.reflector','metadata.touch_event','metadata.initial_condition','metadata.grip'],
               values=COUNT_OF_TOUCH_EVENTS,
               columns=['metadata.system.firmware.serialno'],
               aggfunc=np.mean)

# %% [markdown]
# ###Count of all false positives in negative (touch) test set

# %%
count_of_touch_events = df_neg_touch.pivot_table(values=['results.metrics.prox.at_touch.ir.all.lt_threshold','results.metrics.prox.at_touch.us.all.lt_threshold','results.metrics.prox.at_touch.us.all.detected'], 
                        index=['touch_row','touch_col','touch_angle'],
                        aggfunc=agg_func_sum_of_length_of_arrays)
count_of_touch_events.unstack('touch_col')

# %%
count_of_false_positives = df_neg_touch.pivot_table(values=['results.metrics.prox.at_touch.ir.all.lt_threshold','results.metrics.prox.at_touch.us.all.lt_threshold','results.metrics.prox.at_touch.us.all.detected'], 
                        index=['touch_row','touch_col'],
                        aggfunc=agg_func_sum_of_number_of_true_elements_in_arrays)
count_of_false_positives

# %% [markdown]
# ###Statistics for negative (touch) test set

# %%
FP_METRIC = ULTRASOUND_PROX_DATA_ALL_TOUCHES
count_of_touch_events = df_neg_touch.groupby(by=['touch_row','touch_col','touch_angle'])[FP_METRIC].apply(agg_func_sum_of_length_of_arrays).unstack('touch_col')
count_of_false_positives = df_neg_touch.groupby(by=['touch_row','touch_col','touch_angle'])[FP_METRIC].apply(agg_func_sum_of_number_of_true_elements_in_arrays).unstack('touch_col')
fp_rate = count_of_false_positives / count_of_touch_events
fp_rate

# %%
#Table
FP_METRIC = ULTRASOUND_PROX_NEAR_ALL_TOUCHES
count_of_touch_events = df_neg_touch.groupby(by=['touch_row','touch_col','touch_angle'])[FP_METRIC].apply(agg_func_sum_of_length_of_arrays).unstack('touch_col')
count_of_false_positives = df_neg_touch.groupby(by=['touch_row','touch_col','touch_angle'])[FP_METRIC].apply(agg_func_sum_of_number_of_true_elements_in_arrays).unstack('touch_col')
fp_rate = count_of_false_positives / count_of_touch_events
fp_rate

# %%
this_df = df_neg_touch
FP_METRIC = ULTRASOUND_PROX_NEAR_ALL_TOUCHES

param_name = 'touch_angle'

unique_params = this_df[param_name].unique()
unique_params_cnt = len(unique_params)
fig, all_axes = plt.subplots(unique_params_cnt, 1)
# Matplotlib is ridiculous and returns a scalar instead of an array if the number of plots is one, hence:
if type(all_axes) != type(np.array([])):
    all_axes = np.asarray([all_axes])


for idx, this_param in enumerate(unique_params):
    subset_idx = (this_df[param_name] == this_param)

    count_of_touch_events = df_neg_touch[subset_idx].groupby(by=['touch_row','touch_col'])[FP_METRIC].apply(agg_func_sum_of_length_of_arrays).unstack('touch_col')
    count_of_false_positives = df_neg_touch[subset_idx].groupby(by=['touch_row','touch_col'])[FP_METRIC].apply(agg_func_sum_of_number_of_true_elements_in_arrays).unstack('touch_col')
    fp_rate = count_of_false_positives / count_of_touch_events
    hm = sns.heatmap(fp_rate*100,
                     annot=True,
                     fmt="0.1f",
                    ax=all_axes[idx],
                     vmin=0,
                    vmax=100,
                    annot_kws={'fontsize':12})
    
    subplot_title = param_name + ': ' + this_param
    if idx == 0:
        subplot_title = 'False Positives:\nProbability of '+FP_METRIC+'\n'+subplot_title
    hm.set_title(subplot_title)
    
plt.tight_layout() 
plt.savefig(results.PLOT_FOLDER+'Heatmap_of_ultrasound_false_positives.png',dpi=200)

# %%
this_df = df_neg_touch
FP_METRIC = INFRARED_PROX_NEAR_ALL_TOUCHES

param_name = 'touch_angle'

unique_params = this_df[param_name].unique()
unique_params_cnt = len(unique_params)
fig, all_axes = plt.subplots(unique_params_cnt, 1)
# Matplotlib is ridiculous and returns a scalar instead of an array if the number of plots is one, hence:
if type(all_axes) != type(np.array([])):
    all_axes = np.asarray([all_axes])


for idx, this_param in enumerate(unique_params):
    subset_idx = (this_df[param_name] == this_param)

    count_of_touch_events = df_neg_touch[subset_idx].groupby(by=['touch_row','touch_col'])[FP_METRIC].apply(agg_func_sum_of_length_of_arrays).unstack('touch_col')
    count_of_false_positives = df_neg_touch[subset_idx].groupby(by=['touch_row','touch_col'])[FP_METRIC].apply(agg_func_sum_of_number_of_true_elements_in_arrays).unstack('touch_col')
    fp_rate = count_of_false_positives / count_of_touch_events
    hm = sns.heatmap(fp_rate*100,
                     annot=True,
                     fmt="0.1f",
                    ax=all_axes[idx],
                     vmin=0,
                    vmax=100,
                    annot_kws={'fontsize':12})
    
    subplot_title = param_name + ': ' + this_param
    if idx == 0:
        subplot_title = 'False Positives:\nProbability of '+FP_METRIC+'\n'+subplot_title
    hm.set_title(subplot_title)
    
plt.tight_layout() 
plt.savefig(results.PLOT_FOLDER+'Heatmap_of_infrared_false_positives.png',dpi=200)

# %%
this_df = df_neg_touch
FP_METRIC = ULTRASOUND_PROX_DATA_ALL_TOUCHES

param_name = 'touch_angle'

unique_params = this_df[param_name].unique()
unique_params_cnt = len(unique_params)
fig, all_axes = plt.subplots(unique_params_cnt, 1)
# Matplotlib is ridiculous and returns a scalar instead of an array if the number of plots is one, hence:
if type(all_axes) != type(np.array([])):
    all_axes = np.asarray([all_axes])

agg_func_sum_of_distance = lambda x: sum([sum(y[y>=0]) for y in x])

for idx, this_param in enumerate(unique_params):
    subset_idx = (this_df[param_name] == this_param)

    sum_of_distances = df_neg_touch[subset_idx].groupby(by=['touch_row','touch_col'])['results.metrics.prox.at_touch.us.all.r'].apply(agg_func_sum_of_distance).unstack('touch_col')
    count_of_touch_events = df_neg_touch[subset_idx].groupby(by=['touch_row','touch_col'])[FP_METRIC].apply(agg_func_sum_of_number_of_true_elements_in_arrays).unstack('touch_col')
    average_distance = sum_of_distances / count_of_touch_events
    hm = sns.heatmap(average_distance,
                     annot=True,
                     fmt="0.1f",
                    ax=all_axes[idx],
                     vmin=0,
                    vmax=160,
                    annot_kws={'fontsize':12},
                    cbar_kws={'label':'distance [mm]'})
    
    subplot_title = param_name + ': ' + this_param
    if idx == 0:
        subplot_title = 'False Positives: Average of '+FP_METRIC+'\n'+subplot_title
    hm.set_title(subplot_title)
    
plt.tight_layout() 
plt.savefig(results.PLOT_FOLDER+'Heatmap_of_average_distance_detection_ultrasound',dpi=200)

# %% [markdown]
# ###Average distance measured at touch event

# %%
FP_METRIC = ULTRASOUND_PROX_DATA_ALL_TOUCHES
sum_of_distances = df_neg_touch.groupby(by=['touch_row','touch_col','touch_angle'])['results.metrics.prox.at_touch.us.all.r'].apply(agg_func_sum_of_distance).unstack('touch_col')
count_of_touch_events = df_neg_touch.groupby(by=['touch_row','touch_col','touch_angle'])[FP_METRIC].apply(agg_func_sum_of_number_of_true_elements_in_arrays).unstack('touch_col')
sum_of_distances / count_of_touch_events

# %% [markdown]
# ###List of distances at touch events

# %%
FP_METRIC = ULTRASOUND_PROX_DATA_ALL_TOUCHES
all_distances = df_neg_touch.groupby(by=['touch_row','touch_col','touch_angle'])['results.metrics.prox.at_touch.us.all.r'].apply(lambda x: [y[y>=0] for y in x]).unstack('touch_col')
x=all_distances.to_html()
all_distances

# %% [markdown]
# ###Statistics for negative (no touch) test set

# %%
mydf=pd.DataFrame(data={'a': [[1,2,3],[2,3],[3]], 'b': [3,4,None]})
mydf['c'] = mydf.apply(lambda x: x['a'], axis=1)
mydf['c'] = mydf['c'].apply(np.asarray)
#mydf['c'].apply(lambda x: x+1)
mydf['c'].apply(np.asarray)

# %%
ACCEPT_US_EVENTS = ['UltrasoundIntermediate', 'UltrasoundBegin']
#for idx in np.arange(1,44,1):
#    print np.asarray(df_neg_no_touch['data.output.parsed.us.r'][df_neg_no_touch.index[idx]])
df_neg_no_touch.apply(lambda x: np.asarray(x['data.output.parsed.us.r']), axis=1)
#df_neg_no_touch.apply(lambda x: np.asarray(x['data.output.parsed.us.r'])[np.asarray([y in ACCEPT_US_EVENTS for y in x['data.output.parsed.us.type']]) < 20], axis=1)

#df_neg_no_touch.apply(lambda x: np.array(x['data.output.parsed.us.r']) if len(x['data.output.parsed.us.r']) else None, axis=1)
#df_neg_no_touch['data.output.derived.us.r_no_end'] = df_neg_no_touch.apply(lambda x: np.asarray(x['data.output.parsed.us.r'])[np.asarray([y in ACCEPT_US_EVENTS for y in x['data.output.parsed.us.type']]) < 20] if len(x['data.output.parsed.us.r']) else None, axis=1)
#df_neg_no_touch['data.output.derived.us.r_no_end.min'] = df_neg_no_touch['data.output.derived.us.r_no_end'].apply(lambda x: x.min() if x is not None else None)

# %%
# This gives min distance for false positives (no)
df_neg_no_touch['data.output.derived.us.r.no_end.min'] 
df_neg_no_touch.pivot_table(columns=['metadata.reflector','metadata.initial_condition','metadata.grip'], values='data.output.derived.us.r.no_end.min', aggfunc=[np.min, np.median, np.max])

# %%
df_neg_no_touch['metadata.ID']

# %%
# Barplot of counts (not normalized)
grouped_pos = df_neg_no_touch.groupby(
    ["metadata.initial_condition",
     "metadata.reflector",
     "metadata.touch_event",
     ULTRASOUND_PROX_NEAR_AT_FIRST_TOUCH])
grouped_pos_us_detected = grouped_pos['_id'].count().unstack(ULTRASOUND_PROX_NEAR_AT_FIRST_TOUCH).fillna(0)
barplot = grouped_pos_us_detected.plot(kind='barh', stacked=True, legend=True)
barplot.set_ylabel('Initial condition, Reflector, Touch event')
barplot.set_xlabel('Count of tests')
barplot.set_title('Count of ultrasound proximity at first touch\nFalse: proximity failure, True: proximity success')
plt.tight_layout()
plt.savefig(results.PLOT_FOLDER+'Count_of_ultrasound_proximity_at_first_touch.png',dpi=200)
